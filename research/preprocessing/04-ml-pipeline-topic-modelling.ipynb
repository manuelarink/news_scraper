# %% [markdown]
# # Machine Learning Pipeline for Topic Modelling

# %% [markdown]
# The dataset that is provided here was scraped from different rss-feeds in between 06-2022 and 09-2023 as base for a Data Science and Machine Learning project. The project focusses on performing exploratory data analysis, gaining insights from the data, performing topic modelling and learning basic techniques.
#
# The dataset is stored in csv-textfiles as well as in a PostgreSQL-database.
# It consists of the following columns:
# - id:
# - date:
# - title:
# - description:
# - author:
# - category:
# - copyright:
# - url:
# - text:
# - source:

# %% [markdown]
# This pipeline is designed for loading the data from a postgresql database, performing feature engineering and building a ML model for clustering the news into different topics (unsupervised learning) and compare them with the labeled categories.

# %% [markdown]
# ## Imports

# %%
# data manipulation and plotting
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# loading data from postgresql database 
import sqlalchemy as sql

from datetime import datetime

# saving the pipeline
import joblib

# from scikit-learn
from sklearn.model_selection import train_test_split

# from feature-engine
from feature_engine.imputation import CategoricalImputer, AddMissingIndicator
from feature_engine.encoding import RareLabelEncoder
from feature_engine.selection import DropFeatures

# from preprocessors
import preprocessors as pp

# %% [markdown]
# ## Load the data from database

# %% [markdown]
# The entries of the dataset are recorded up from June 2022.
# The modell will be trained and tested with data from 01.06.2022 to 30.09.2023. Data up from 01.10.2023 will be treated as new data and just used for prediction.

# %%
# connect to db
engine = sql.create_engine('postgresql+psycopg2://news:news@localhost:5432/news')
con = engine.connect()

start_date = datetime(2022, 6, 1, 0, 0, 0)
end_date = datetime(2023, 9, 30, 23, 59, 59)

with con:
    
    # query data for model training and testing
    query = sql.text("""
        SELECT *
        FROM headlines
        WHERE (date >= :start_date
        AND date <= :end_date)
        ORDER BY date ASC
        """)
    result = con.execute(query, start_date=start_date, end_date=end_date)
    train_test = pd.DataFrame(result.fetchall(), columns=result.keys())

    # query data for prediction
    query = sql.text("""
        SELECT *
        FROM headlines
        WHERE (date > :end_date)
        ORDER BY date ASC
        """)
    result = con.execute(query, end_date=end_date)
    pred = pd.DataFrame(result.fetchall(), columns=result.keys())

# %%
train_test.head()
# Out:
#       id                date  \
# 0  71650 2022-06-01 00:13:42
# 1  71649 2022-06-01 01:55:03
# 2  71648 2022-06-01 02:04:08
# 3  71675 2022-06-01 02:26:58
# 4  71647 2022-06-01 02:31:43
#
#                                                title  \
# 0  Preise: Grüne halten Senkung der Spritsteuer f...
# 1  Biden warnt Putin: USA liefern moderne Raketen...
# 2  Soziale Medien: FDP-Politiker Kuhle: Internet-...
# 3  Liveblog: ++ Zwei von drei ukrainischen Kinder...
# 4  Finanzen: Dänemark stimmt über EU-Verteidigung...
#
#                                          description author  \
# 0  Heute tritt die Steuersenkung auf Kraftstoffe ...   None
# 1  Die USA rüsten die Ukraine mit fortschrittlich...   None
# 2  Eine «ZDF Magazin Royale»-Recherche beschäftig...   None
# 3  Rund zwei von drei Mädchen und Jungen in der U...   None
# 4  Vorbehalt verteidigen oder Verteidigung ohne V...   None
#
#                                             category copyright  \
# 0  Steuersenkung, Bundestag, Katharina Dröge, Spr...      None
# 1  Ukraine, USA, Joe Biden, Russland, Raketensyst...      None
# 2  Konstantin Kuhle, FDP, Straftat, Berlin, ZDF, ...      None
# 3                                               None      None
# 4  Dänemark, EU, Volksabstimmung, Finanzen, Ukrai...      None
#
#                                                  url  text      source
# 0  https://www.stern.de/politik/deutschland/preis...  None       stern
# 1  https://www.stern.de/politik/ausland/biden-war...  None       stern
# 2  https://www.stern.de/politik/deutschland/sozia...  None       stern
# 3  https://www.tagesschau.de/newsticker/liveblog-...  None  Tagesschau
# 4  https://www.stern.de/politik/ausland/finanzen-...  None       stern

# %%
print(train_test.shape)
# Out:
# (75461, 10)

# %%
pred.head()
# Out:
#       id                date  \
# 0  85639 2023-10-01 09:03:00
# 1  85434 2023-10-01 09:18:18
# 2  85435 2023-10-01 11:25:35
# 3  85601 2023-10-01 12:06:00
# 4  85651 2023-10-01 14:11:00
#
#                                                title  \
# 0                             Frauen für den Frieden
# 1  PKK hatte sich bekannt - Türkei greift nach An...
# 2  Gastbeitrag von Gabor Steingart - Unbequeme Pu...
# 3             Was ist dran an Söders Berlin-Bashing?
# 4        Trübe Wirtschaftslage - Lotto-Boom in China
#
#                                          description author  \
# 0  Jolina und Louisa setzen sich in Nordirland fü...   None
# 1  Die türkische Hauptstadt Ankara ist am Sonntag...   None
# 2  Für 2023 erwartet Russland ein Wirtschaftswach...   None
# 3  "Wir sind solidarisch, aber nicht naiv", sagt ...   None
# 4  Chinas Wirtschaft kämpft mit einem geringeren ...   None
#
#                       category copyright  \
# 0                37 Grad Leben      None
# 1                      Ausland      None
# 2                      Ausland      None
# 3                      Politik      None
# 4  Hohe Jugendarbeitslosigkeit      None
#
#                                                  url  text     source
# 0  https://www.zdf.de/dokumentation/37-grad-leben...  None  ZDF heute
# 1  https://www.focus.de/politik/ausland/tuerkisch...  None      Focus
# 2  https://www.focus.de/politik/ausland/gastbeitr...  None      Focus
# 3  https://www.zdf.de/nachrichten/politik/laender...  None  ZDF heute
# 4  https://www.zdf.de/nachrichten/wirtschaft/chin...  None  ZDF heute

# %%
print(pred.shape)
# Out:
# (262, 10)

# %% [markdown]
# ## Save raw data for train_test and pred to csv

# %%
train_test.to_csv('../data/00_train_test_raw.csv')
pred.to_csv('../data/00_pred_raw.csv')

# %% [markdown]
# ## Feature Engineering on train_test

# %% [markdown]
# ### Split the data into train and test set

# %%
train, test = train_test_split(train_test, test_size=0.2, random_state=42)

# %%
train.head()
# Out:
#           id                date  \
# 69435  79401 2023-08-21 12:13:29
# 40748  35571 2023-01-21 10:11:00
# 57437  52069 2023-04-29 20:10:21
# 7205    2350 2022-06-27 06:51:59
# 4879   76333 2022-06-20 05:25:57
#
#                                                    title  \
# 69435  F-16 für Ukraine - Lawrow warnt Westen vor „in...
# 40748               Nur Wellinger überzeugt, Kraft siegt
# 57437  Angela Merkel: Angela Merkel verteidigt ihre R...
# 7205   G7-Gipfel in Elmau im Newsticker - G7-Gegner d...
# 4879   Russische Invasion: Krieg in der Ukraine: So i...
#
#                                              description author  \
# 69435  Während der Westen plant, F-16-Kampfflugzeuge ...   None
# 40748                               Nachrichtlich texten   None
# 57437  Trotz des Ukraine-Kriegs hält die Altkanzlerin...   None
# 7205   Der 48. G7-Gipfel findet vom 26. bis 28. Juni ...   None
# 4879                                                None   None
#
#                   category copyright  \
# 69435        Ukraine-Krise      None
# 40748  Sport | Wintersport      None
# 57437          Deutschland      None
# 7205               Politik      None
# 4879                  News      None
#
#                                                      url  text     source
# 69435  https://www.focus.de/politik/ausland/ukraine-k...  None      Focus
# 40748  https://www.zdf.de/sport/wintersport/skispring...  None  ZDF heute
# 57437  https://www.zeit.de/politik/deutschland/2023-0...  None       Zeit
# 7205   https://www.focus.de/politik/g7-gipfel-in-elma...  None      Focus
# 4879   https://www.zeit.de/news/2022-06/20/krieg-in-d...  None       Zeit

# %%
print(train.shape)
# Out:
# (60368, 10)

# %%
print(train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60368 entries, 69435 to 15795
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           60368 non-null  int64
#  1   date         60368 non-null  datetime64[ns]
#  2   title        60231 non-null  object
#  3   description  57221 non-null  object
#  4   author       1185 non-null   object
#  5   category     39009 non-null  object
#  6   copyright    0 non-null      object
#  7   url          60235 non-null  object
#  8   text         0 non-null      object
#  9   source       60368 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 5.1+ MB
# None

# %%
test.head()
# Out:
#           id                date  \
# 29368  24143 2022-10-09 19:49:00
# 34216  28909 2022-11-30 03:00:34
# 75397  85305 2023-09-29 05:43:55
# 46409  41081 2023-02-24 18:25:44
# 16931  11693 2022-07-28 10:18:36
#
#                                                    title  \
# 29368  SPD-Kandidat gewinnt Oberbürgermeisterwahl in ...
# 34216  Als es um den Ukraine-Krieg geht, gerät Alice ...
# 75397  ARD-Deutschlandtrend: Zwei Drittel der Deutsch...
# 46409  Energiemonitor: Die wichtigsten Daten zur Ener...
# 16931     Öffentliche Schulden Ende 2021 auf Höchststand
#
#                                              description author     category  \
# 29368  In Cottbus hat SPD-Kandidat Tobias Schick die ...   None  Deutschland
# 34216  In der Talkshow von Sandra Maischberger bekräf...   None     Panorama
# 75397  Weniger als jeder Fünfte ist laut einer Umfrag...   None  Deutschland
# 46409  Ukraine-Krieg und Klimakrise: Deutschland muss...   None   Wirtschaft
# 16931  Die öffentliche Verschuldung ist Ende 2021 auf...   None         None
#
#       copyright                                                url  text  \
# 29368      None  https://www.welt.de/politik/deutschland/articl...  None
# 34216      None  https://www.welt.de/vermischtes/article2424008...  None
# 75397      None  https://www.zeit.de/politik/deutschland/2023-0...  None
# 46409      None  https://www.zeit.de/wirtschaft/energiemonitor-...  None
# 16931      None  https://www.tagesschau.de/wirtschaft/konjunktu...  None
#
#            source
# 29368        Welt
# 34216        Welt
# 75397        Zeit
# 46409        Zeit
# 16931  Tagesschau

# %%
print(test.shape)
# Out:
# (15093, 10)

# %%
print(test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15093 entries, 29368 to 64527
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           15093 non-null  int64
#  1   date         15093 non-null  datetime64[ns]
#  2   title        15065 non-null  object
#  3   description  14323 non-null  object
#  4   author       284 non-null    object
#  5   category     9785 non-null   object
#  6   copyright    0 non-null      object
#  7   url          15065 non-null  object
#  8   text         0 non-null      object
#  9   source       15093 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 1.3+ MB
# None

# %% [markdown]
# ### Configuration

# %%
# features to drop
DROP_FEATURES = ['id', 'copyright', 'author', 'url']

# variables with duplicates
VARS_WITH_DUPLICATES = ['title', 'description']

# variables with NA and frequent values in train set
VARS_WITH_NA_FREQUENT = ['category']

# variables with NA in train set that will be filled with 'Missing' value
VARS_WITH_NA_MISSING = ['source', 'title', 'description', 'text']

# variables to be combined 
VARS_TO_COMBINE = ('title_description_text', ['title', 'description', 'text'])

# features that are used for topic modelling (for each feature a modell will be trained)
FEATURES = ['title', 'title_description_text']
